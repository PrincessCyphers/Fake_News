# %%
import pandas as pd # data processing
import numpy as np # linear algebra
import matplotlib.pyplot as plt # plotting and graphs

# import kaggle

# %%
# to access structure of directory

import os

# %%
# to view csv files in downloaded dataset 

csv_files = os.listdir(r"/Users/Taurai/Iza/CFG/Data Science : Part 2/Project Folder /CoAID-0.4/11-01-2020")
for file in csv_files: 
    print(file)
print((csv_files.count))
# Out:
# NewsFakeCOVID-19_tweets_replies.csv
# NewsRealCOVID-19_tweets.csv
# NewsFakeCOVID-19_tweets.csv
# NewsRealCOVID-19.csv
# NewsRealCOVID-19_tweets_replies.csv
# ClaimRealCOVID-19_tweets.csv
# ClaimRealCOVID-19.csv
# ClaimRealCOVID-19_tweets_replies.csv
# NewsFakeCOVID-19.csv
# <built-in method count of list object at 0x7fa0a6425fc0>

# %%
# choosing to use only the news articles 
df1 = pd.read_csv("/Users/Taurai/Iza/CFG/Data Science : Part 2/Project Folder /CoAID-0.4/11-01-2020/NewsFakeCOVID-19.csv")
df2 = pd.read_csv("/Users/Taurai/Iza/CFG/Data Science : Part 2/Project Folder /CoAID-0.4/11-01-2020/NewsRealCOVID-19.csv")

df1.head()
# Out:
#    Unnamed: 0     type                                     fact_check_url  \
# 0         945     post  https://healthfeedback.org/claimreview/there-i...
# 1         946     post  https://healthfeedback.org/claimreview/fewer-f...
# 2         947  article  https://healthfeedback.org/claimreview/claim-t...
# 3         948  article  https://healthfeedback.org/claimreview/covid-1...
# 4         949  article  https://healthfeedback.org/claimreview/masks-a...
#
#                    archieve  \
# 0  https://archive.is/ANIz3
# 1  https://archive.vn/PZXdL
# 2  https://archive.is/yM6lX
# 3  https://archive.is/4rNH7
# 4  https://archive.is/SbeCt
#
#                                             news_url news_url2 news_url3  \
# 0        https://www.youtube.com/watch?v=aHRNvAIFSMU       NaN       NaN
# 1  https://twitter.com/DonaldJTrumpJr/status/1320...       NaN       NaN
# 2  https://www.newsnationnow.com/health/coronavir...       NaN       NaN
# ...

# %%
df2.head()
# Out:
#    Unnamed: 0     type  fact_check_url  \
# 0        3533  article  healthline.com
# 1        3534  article  healthline.com
# 2        3535  article  healthline.com
# 3        3536  article  healthline.com
# 4        3537  article  healthline.com
#
#                                             news_url  \
# 0  https://www.healthline.com/health-news/the-us-...
# 1  https://www.healthline.com/health-news/hospita...
# 2  https://www.healthline.com/health-news/new-evi...
# 3  https://www.healthline.com/health-news/adults-...
# 4  https://www.healthline.com/health-news/aspirin...
#
#                                                title  \
# 0  The U.S. Is Likely Headed for a ‘Dark Winter.’...
# 1  Hospitals May Have to Ration Care as COVID-19 ...
# 2  New Evidence That Coronavirus Antibodies Only ...
# 3  Adults Under 30 Least Likely to Wear Mask, Soc...
# 4  Aspirin May Help Prevent Serious COVID-19 Comp...
#
#                                            newstitle  \
# ...

# %%
# remove empty tertiary urls in fake news
