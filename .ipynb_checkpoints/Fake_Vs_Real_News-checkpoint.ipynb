# %%
import pandas as pd # data processing 
import matplotlib.pyplot as plt # plotting 
import numpy as np # linear algebra 
import seaborn as sns 

# tool for reading data csv file (faster than pandas and reads from .zip)
import datatable as dt 

# import kaggle 

# colored output text
from termcolor import colored

import re
import string 

from wordcloud import WordCloud, STOPWORDS

# Silent Warnings 
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# ### Dataset in use
# ### https://www.kaggle.com/datasets/clmentbisaillon/fake-and-real-news-dataset?select=True.csv

# %%
fake_df1 = pd.read_csv("./archive(3)/Fake.csv")
real_df1 = pd.read_csv("./archive(3)/True.csv")

# %% [markdown]
# ### Quick exploratory analysis of Fake News DF

# %%
fake_df1.head(6)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# 5  The number of cases of cops brutalizing and ki...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017
# 5  December 25, 2017

# %%
fake_df1.describe()
# Out:
#                                                     title   text subject  \
# count                                               23481  23481   23481
# unique                                              17903  17455       6
# top     MEDIA IGNORES Time That Bill Clinton FIRED His...           News
# freq                                                    6    626    9050
#
#                 date
# count          23481
# unique          1681
# top     May 10, 2017
# freq              46

# %%
fake_df1.shape
# Out:
# (23481, 4)

# %%
fake_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB

# %%
fake_df1.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %% [markdown]
# #### Let's find and remove duplicates in Fake DF

# %%
duplicate = fake_df1['text'][fake_df1['text'].duplicated()].index
result = f"Found {len(duplicate)} duplicates in {fake_df1.shape[0]} samples"
print(colored(result, 'blue', attrs=['bold']))
# Out:
# Found 6026 duplicates in 23481 samples

# %%
# remove duplicates 

fake_df1.drop(index=duplicate, inplace=True)
fake_df1.shape
# Out:
# (17455, 4)

# %%
fake_df1['subject'].unique()
# Out:
# array(['News', 'politics', 'Government News', 'left-news', 'US_News'],
#       dtype=object)

# %% [markdown]
# ### Quick explanatory analysis of Real News DF

# %%
real_df1.head(6)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
# 5  White House, Congress prepare for talks on spe...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# 5  WEST PALM BEACH, Fla./WASHINGTON (Reuters) - T...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017
# 5  December 29, 2017

# %%
real_df1.describe()
# Out:
#                                                     title  \
# count                                               21417
# unique                                              20826
# top     Factbox: Trump fills top jobs for his administ...
# freq                                                   14
#
#                                                      text       subject  \
# count                                               21417         21417
# unique                                              21192             2
# top     (Reuters) - Highlights for U.S. President Dona...  politicsNews
# freq                                                    8         11272
#
#                       date
# count                21417
# unique                 716
# top     December 20, 2017
# freq                   182

# %%
real_df1.shape
# Out:
# (21417, 4)

# %%
real_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21417 entries, 0 to 21416
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    21417 non-null  object
#  1   text     21417 non-null  object
#  2   subject  21417 non-null  object
#  3   date     21417 non-null  object
# dtypes: object(4)
# memory usage: 669.4+ KB

# %%
real_df1.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %% [markdown]
# #### Let's Find and remove duplicates in Real DF

# %%
duplicate = real_df1['text'][real_df1['text'].duplicated()].index
result = f"Found {len(duplicate)} duplicates in {real_df1.shape[0]} samples"
print(colored(result, 'blue', attrs=['bold']))
# Out:
# Found 225 duplicates in 21417 samples

# %%
real_df1.drop(index=duplicate, inplace=True)
real_df1.shape
# Out:
# (21192, 4)

# %%
real_df1['subject'].value_counts()
# Out:
# politicsNews    11214
# worldnews        9978
# Name: subject, dtype: int64

# %% [markdown]
# ### Let's add 'true' label for easier reference where Fake = 0, Real = 1

# %%
# label the diff df for easier ref

fake_df1['true'] = 0
real_df1['true'] = 1

# print new shape 
print(fake_df1.shape)
print(real_df1.shape)
# Out:
# (17455, 5)
# (21192, 5)

# %%
# just to see 

real_df1.describe
# Out:
# <bound method NDFrame.describe of                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...     worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...     worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...     worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...     worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...     worldnews
#
#                      date  true
# 0      December 31, 2017      1
# 1      December 29, 2017      1
# 2      December 31, 2017      1
# 3      December 30, 2017      1
# 4      December 29, 2017      1
# ...                   ...   ...
# 21412    August 22, 2017      1
# 21413    August 22, 2017      1
# 21414    August 22, 2017      1
# 21415    August 22, 2017      1
# 21416    August 22, 2017      1
#
# [21192 rows x 5 columns]>

# %%
# concat the two datasets  

raw_df = pd.concat([fake_df1, real_df1], ignore_index = True)
raw_df
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 38642  'Fully committed' NATO backs new U.S. approach...
# 38643  LexisNexis withdrew two products from Chinese ...
# 38644  Minsk cultural hub becomes haven from authorities
# 38645  Vatican upbeat on possibility of Pope Francis ...
# 38646  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# 3      On Christmas day, Donald Trump announced that ...       News
# 4      Pope Francis used his annual Christmas Day mes...       News
# ...                                                  ...        ...
# 38642  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 38643  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 38644  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 38645  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 38646  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                     date  true
# 0      December 31, 2017     0
# 1      December 31, 2017     0
# 2      December 30, 2017     0
# 3      December 29, 2017     0
# 4      December 25, 2017     0
# ...                  ...   ...
# 38642   August 22, 2017      1
# 38643   August 22, 2017      1
# 38644   August 22, 2017      1
# 38645   August 22, 2017      1
# 38646   August 22, 2017      1
#
# [38647 rows x 5 columns]

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38647 entries, 0 to 38646
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    38647 non-null  object
#  1   text     38647 non-null  object
#  2   subject  38647 non-null  object
#  3   date     38647 non-null  object
#  4   true     38647 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 1.5+ MB

# %%
# How many are real, and how many are fake? 

raw_df.true.value_counts()
# Out:
# 1    21192
# 0    17455
# Name: true, dtype: int64

# %% [markdown]
# ### Let's visualise raw_df before any cleaning to allow comparison

# %%
# spread of information sources/ subjects in raw df 

plt.figure(figsize=(10,6))
sns.countplot('subject', data = raw_df)
plt.show()

# %%
# group by subject and by true score
raw_df.groupby('subject')['true'].count()
# Out:
# subject
# Government News      514
# News                9050
# US_News              783
# left-news            683
# politics            6425
# politicsNews       11214
# worldnews           9978
# Name: true, dtype: int64

# %%
# plot the grouped with seaborn and matplotlib
sns.histplot(raw_df, y='subject', hue ='true', 
           stat = 'percent', multiple = 'stack',
           palette = 'coolwarm')
plt.ylabel('Subject of News Source')
plt.title('Breakdown of Fake Vs Real News in Dataset')
plt.legend(title='News', loc='upper right', labels = ['Fake', 'Real'])

# %% [markdown]
# #### Let's change politicsNews to politics, News to worldnews and plot again
# #### This allows easier comparison of news subject for fake and real news

# %%
raw_df['subject'].replace({'politicsNews':'politics', 
                           'News':'worldnews'}, inplace = True)

sns.histplot(raw_df, y='subject', hue ='true', 
           stat = 'percent', multiple = 'stack',
           palette = 'coolwarm')
plt.ylabel('Subject of News Source')
plt.title('Breakdown of Fake Vs Real News in Dataset')
plt.legend(title='News', loc='lower right', labels = ['Fake', 'Real'])

# %% [markdown]
# #### Let's make a word cloud of the text for quick comparison of article content before cleaning and processing.

# %%
fake_text = raw_df.text[raw_df['true']==0]
real_text = raw_df.text[raw_df['true']==1]

def plot_fake_vs_real(fake, real):
    wordcloud_fake = WordCloud(width = 2000, height = 1300,
                              background_color = 'white', 
                              stopwords = STOPWORDS).generate(str(fake))
    wordcloud_real = WordCloud(width = 2000, height = 1300,
                              background_color = 'white', 
                              stopwords = STOPWORDS).generate(str(real))
    
    # plot WordCloud img 
    plt.subplots(figsize=(15,6))
    
    plt.subplot(1,3,1)
    plt.imshow(wordcloud_fake, interpolation = 'bilinear')
    plt.axis('off')
    plt.tight_layout(pad=0)
    
    plt.suptitle("Fake(left) vs Real(right)", y=0.5, va='center', size = 24)
    
    plt.subplot(1,3,3)
    plt.imshow(wordcloud_real, interpolation = 'bilinear')
    plt.axis('off')
    plt.tight_layout(pad=0)

    
plot_fake_vs_real(fake_text, real_text)
plt.show()

# %% [markdown]
# #### Let's add a wordcloud of title words too, to show what words are used as click / read-bait

# %%
fake_title = raw_df.title[raw_df['true']==0]
real_title = raw_df.title[raw_df['true']==1]

plot_fake_vs_real(fake_title, real_title)
plt.show()

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Df needs cleaning. Ultimate Goal is:
# * Check for null values
# * check for empty spaces
# * check for nonsense texts
# * remove urls, https, special characters and numbers
# * remove REUTERS()

# %%
# check raw_df starting point
raw_df.shape
# Out:
# (38647, 5)

# %%
# check null values
raw_df.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# true       0
# dtype: int64

# %%
duplicate = raw_df['text'][raw_df['text'].duplicated()].index
result = f"Found {len(duplicate)} duplicate in {raw_df.shape[0]} samples"
print(colored(result, 'blue', attrs=['bold']))
# Out:
# Found 1 duplicate in 38647 samples

# %%
raw_df.drop(index=duplicate, inplace=True)
raw_df.shape
# Out:
# (38646, 5)

# %%
# how many have <CITY>(Reuters) pattern in text 
# pattern = 0+ uppercase letters, 0 or 1 spaces, (Reuters)

pattern = r'[A-Z]* ?\(Reuters\)'

test_df = raw_df['text'].copy().to_frame()
test_df['patterns'] = test_df['text'].map(lambda x: len(re.findall(pattern, x)))

result = f"{test_df.groupby('patterns')['text'].count()[1]} of {raw_df.shape[0]} samples have <City> (REUTERS) pattern."
print(colored(result, 'blue', attrs=['bold']))
# Out:
# 21028 of 38646 samples have <City> (REUTERS) pattern.

# %%
# remove pattern <CITY> (Reuters)

raw_df['text'] = raw_df['text'].map(lambda x: re.sub(pattern, '', x))

# %%
raw_df.sample(10)
# Out:
#                                                    title  \
# 26686  Treasury's Lew: China pause on reforms would h...
# 3321    Trump Spent YEARS Browbeating Scotland’s Firs...
# 15731  EPA Chief Reveals Her ‘Trashy’ Upbringing And ...
# 12611  NYC BOMBER’S DAD Reveals Son’s Terrorist Attac...
# 37232  Germany condemns latest North Korea missile te...
# 24286  House Republican offers bill to keep governmen...
# 973     Trump Meeting Privately With Putin, Asked Aid...
# 22475  SEC nominee Clayton vows separation from his W...
# 33256  Turkish passenger plane makes unscheduled stop...
# 5481    WATCH: White Confederate Flag-Waving Redneck ...
#
#                                                     text          subject  \
# 26686   - U.S. Treasury Secretary Jack Lew said on Fr...         politics
# 3321   It s no secret that Donald Trump isn t a fan o...        worldnews
# 15731  EPA Chief Gina McCarthy reveals a bad habit he...  Government News
# 12611   Two years before the bombings that Ahmad Khan...         politics
# 37232   - Germany said on Friday it condemned North K...        worldnews
# 24286   - The Republican head of a House of Represent...         politics
# 973    It looks like Vladimir Putin is going to walk ...        worldnews
# 22475   - Wall Street attorney Jay Clayton will recus...         politics
# 33256   - A Pegasus Airlines plane flying from Moscow...        worldnews
# 5481   The South lost the Civil War but some white gu...        worldnews
#
#                       date  true
# 26686        June 4, 2016      1
# 3321     December 21, 2016     0
# 15731         Jan 12, 2016     0
# 12611         Sep 20, 2016     0
# 37232  September 15, 2017      1
# 24286    December 7, 2016      1
# 973          June 29, 2017     0
# 22475       March 8, 2017      1
# 33256    October 31, 2017      1
# 5481         July 14, 2016     0

# %%
raw_df.describe(include='all')
# Out:
#                                                     title  \
# count                                               38646
# unique                                              38270
# top     Factbox: Trump fills top jobs for his administ...
# freq                                                   14
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                      text    subject  \
# count                                               38646      38646
# unique                                              38646          5
# top     Donald Trump just couldn t wish all Americans ...  worldnews
# freq                                                    1      19028
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#                      date          true
# count               38646  38646.000000
# unique               2397           NaN
# top     December 6, 2017            NaN
# freq                  166           NaN
# mean                  NaN      0.548336
# std                   NaN      0.497665
# min                   NaN      0.000000
# 25%                   NaN      0.000000
# 50%                   NaN      1.000000
# 75%                   NaN      1.000000
# max                   NaN      1.000000

# %%
# Check for empty rows 

raw_df[raw_df['text'].str.strip()=='']
# Out:
#                                                    title text   subject  \
# 10920  TAKE OUR POLL: Who Do You Think President Trum...       politics
# 12032  TRUMP SLAMS THE GLOBALISTS: “There is no globa...       politics
#
#                date  true
# 10920  May 10, 2017     0
# 12032   Dec 1, 2016     0

# %%
# drop the above empty rows 

raw_df = raw_df[raw_df['text'].str.strip()!='']
raw_df.shape
# Out:
# (38644, 5)

# %% [markdown]
# #### Confirm dropped unecessary rows.

# %%
# text has bool true so should return false if empty 
# just another way to check for null values 

all(raw_df['text'].astype(bool))
# Out:
# True

# %% [markdown]
# ### Expand into day, month, year

# %%
# date -> datetime

def get_day_mon_yr(date):
    try: 
        return pd.to_datetime(date, infer_datetime_format = True)
    except:
        return np.nan
    
raw_df['Date'] = raw_df.apply(lambda row: get_day_mon_yr(row['date']), axis = 1)
raw_df.sample(5)
# Out:
#                                                    title  \
# 1785    Local Fox Affiliate Just Gave Fox News A GIAN...
# 32216  Netanyahu signals Israel will act with free ha...
# 23899  U.S. Congress certifies Trump's Electoral Coll...
# 14946  VERY FUNNY VIDEO: SARAH PALIN ADVISES TRUMP TO...
# 10538  BLACK TRUMP SUPPORTER Goes Ballistic On Maxine...
#
#                                                     text    subject  \
# 1785   A local news station in Boston has had it with...  worldnews
# 32216   - Prime Minister Benjamin Netanyahu said on M...  worldnews
# 23899   - The U.S. Congress on Friday certified the E...   politics
# 14946  Just released hysterical video of  Sarah Palin...   politics
# 10538  A woman let it all hang out when she ranted li...   politics
#
#                      date  true       Date
# 1785       April 14, 2017     0 2017-04-14
# 32216  November 13, 2017      1 2017-11-13
# 23899    January 6, 2017      1 2017-01-06
# 14946        Aug 14, 2015     0 2015-08-14
# 10538        Jun 25, 2017     0 2017-06-25

# %%
# check null values (none expected)

raw_df.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# true       0
# Date       6
# dtype: int64

# %%
# check where Date is NaN 

raw_df[raw_df['Date'].isna()]
# Out:
#                                                    title  \
# 9357   https://100percentfedup.com/served-roy-moore-v...
# 15121  https://100percentfedup.com/video-hillary-aske...
# 15122  https://100percentfedup.com/12-yr-old-black-co...
# 15424  https://fedup.wpengine.com/wp-content/uploads/...
# 15425  https://fedup.wpengine.com/wp-content/uploads/...
# 16128                                           Homepage
#
#                                                     text    subject  \
# 9357   https://100percentfedup.com/served-roy-moore-v...   politics
# 15121  https://100percentfedup.com/video-hillary-aske...   politics
# 15122  https://100percentfedup.com/12-yr-old-black-co...   politics
# 15424  https://fedup.wpengine.com/wp-content/uploads/...   politics
# 15425  https://fedup.wpengine.com/wp-content/uploads/...   politics
# 16128  [vc_row][vc_column width= 1/1 ][td_block_trend...  left-news
#
#                                                     date  true Date
# 9357   https://100percentfedup.com/served-roy-moore-v...     0  NaT
# 15121  https://100percentfedup.com/video-hillary-aske...     0  NaT
# 15122  https://100percentfedup.com/12-yr-old-black-co...     0  NaT
# 15424  https://fedup.wpengine.com/wp-content/uploads/...     0  NaT
# 15425  https://fedup.wpengine.com/wp-content/uploads/...     0  NaT
# 16128  MSNBC HOST Rudely Assumes Steel Worker Would N...     0  NaT

# %%
raw_df.shape
# Out:
# (38644, 6)

# %%
# drop the NaN values 

raw_df.dropna(inplace=True)
print(raw_df.shape)
raw_df.sample(5)
# Out:
# (38638, 6)
#                                                    title  \
# 25352  U.S. Sept. 11 law weakens international relati...
# 17557  Republican Senator Collins says she will vote ...
# 28725  Venezuelans scramble to survive as merchants d...
# 4004    Newt Gingrich Unwittingly Makes STARTLING Pre...
# 13606  WEST VIRGINIA COAL MINERS Send A Clear Message...
#
#                                                     text    subject  \
# 25352   - Saudi Arabia said on Monday that a U.S. law...   politics
# 17557   - Republican U.S. Senator Susan Collins said ...   politics
# 28725  CARACAS/CIUDAD GUAYANA, Venezuela - There was ...  worldnews
# 4004   Newt Gingrich, who s totally, utterly and comp...  worldnews
# 13606  West Virginia has been devastated by a loss of...   politics
#
#                      date  true       Date
# 25352    October 3, 2016      1 2016-10-03
# 17557  December 18, 2017      1 2017-12-18
# 28725  December 26, 2017      1 2017-12-26
# 4004     October 30, 2016     0 2016-10-30
# 13606         May 5, 2016     0 2016-05-05

# %%
# Add cols for day, month, year 

raw_df['day']= raw_df.apply(lambda row: row['Date'].day, axis=1)
raw_df['month']= raw_df.apply(lambda row: row['Date'].month, axis =1)
raw_df['year']= raw_df.apply(lambda row: row['Date'].year, axis = 1)

# drop redundant date cols
raw_df.drop(['date','Date'], axis=1, inplace=True)
raw_df.sample(3)
# Out:
#                                                    title  \
# 5492    Trump Attacked Bernie In Series Of Tweets On ...
# 267     Trump In Puerto Rico Disgustingly Tells Puert...
# 25262  Clinton opposition to Asia trade pact 'close c...
#
#                                                     text    subject  true  \
# 5492   Bernie Sanders finally endorsed Hillary Clinto...  worldnews     0
# 267    Just when you thought he couldn t possibly get...  worldnews     0
# 25262  NEW  - Hillary Clinton’s campaign was worried ...   politics     1
#
#        day  month  year
# 5492    13      7  2016
# 267      3     10  2017
# 25262   11     10  2016

# %% [markdown]
# #### Let's plot the correlation between date and target

# %%
sns.heatmap(raw_df[['day', 'month', 'year', 'true']].corr(), annot=True)
sns.set(rc={'figure.figsize':(10,6)})

# %% [markdown]
# ### Check for links in text/ instead of text

# %%
# start with http, ? mean o or one s (https), ://, [^\n ]* any characters except: '\n' (newline), ' ' (0 or more times)
pattern = r'https?://[^\n ]*'

# find how many samples have links in text
test_df = raw_df['text'].copy().to_frame()
test_df['patterns'] = test_df['text'].map(lambda x: len(re.findall(pattern, x)))

text = f"{test_df.groupby('patterns')['text'].count()[1]} of {raw_df.shape[0]} samples have a link in them"
print(colored(text, 'blue', attrs=['bold']))
# Out:
# 1900 of 38638 samples have a link in them

# %%
# remove links 
raw_df['text'] = raw_df['text'].map(lambda x: re.sub(pattern, '', x))

# %%
#  check how many strings had just the link in text columns 

text = f"{raw_df.text[raw_df['text'].str.strip()==''].count()} samples had links instead of news text"
print(colored(text, 'blue', attrs=['bold']))

raw_df[raw_df['text'].str.strip()==''].sample(5)
# Out:
# 48 samples had links instead of news text
#                                                    title text   subject  true  \
# 12038  THE VIEW’S Whoopi Goldberg To Co-Host: “This I...       politics     0
# 11809  EPIC! RICK SANTELLI Calls Out Liberal Panel: ”...       politics     0
# 11897  KELLYANNE CONWAY On Trump’s Terrorism Policy: ...       politics     0
# 11860  BREAKING: DEMOCRAT Makes Shocking Statement Re...       politics     0
# 11440  NEWT GINGRICH Punches Back At Democrats With M...       politics     0
#
#        day  month  year
# 12038    1     12  2016
# 11809    8      1  2017
# 11897   23     12  2016
# 11860   31     12  2016
# 11440    3      3  2017

# %%
# remove the 48 samples without text
raw_df = raw_df[raw_df['text'].str.strip()!='']
raw_df.shape
# Out:
# (38590, 7)

# %% [markdown]
# ### Unique chars in text

# %% [markdown]
# #### Let's plot the length of unique characters in the text, and 'true-value'

# %%
# count unique alphabet characters in text of each article 

def unique_char_num(string): 
    lower_str = string.lower()
    alpha = re.sub(r'[^a-z]','',lower_str)
    unique_ch = set(list(alpha))
    n_unique_ch = len(unique_ch)
    return n_unique_ch 

temp_df = raw_df[['text', 'true']].copy()
temp_df['unique_char'] = temp_df.text.map(lambda x: unique_char_num(x))
temp_df.head()
# Out:
#                                                 text  true  unique_char
# 0  Donald Trump just couldn t wish all Americans ...     0           25
# 1  House Intelligence Committee Chairman Devin Nu...     0           24
# 2  On Friday, it was revealed that former Milwauk...     0           25
# 3  On Christmas day, Donald Trump announced that ...     0           26
# 4  Pope Francis used his annual Christmas Day mes...     0           25

# %%
# sort into descending order by unique_char

to_plot = temp_df.sort_values(by='unique_char', ascending=False).reset_index()

# add text length col to DF 
to_plot['text_len']= to_plot.text.map(lambda x: len(x))
to_plot
# Out:
#        index                                               text  true  \
# 0       9872  President Trump was right again! His campaign ...     0
# 1      29330   - Neither of Peru s two vice presidents would...     1
# 2      29344   - The top U.N. human rights official has said...     1
# 3      29343   - British Prime Minister Theresa May will pit...     1
# 4      10111  Katie Couric s career has been pretty much in ...     0
# ...      ...                                                ...   ...
# 38585  12407                                            Via: GP     0
# 38586  11113                                             Enjoy:     0
# 38587  11846                                            Via: WT     0
# 38588  11676                                            Watch:      0
# 38589  12097                                              Ouch!     0
#
#        unique_char  text_len
# 0               26      2778
# 1               26      4034
# 2               26      2944
# 3               26      2991
# 4               26      1073
# ...            ...       ...
# 38585            5         7
# 38586            5         6
# 38587            5         7
# 38588            5         7
# 38589            4         5
#
# [38590 rows x 5 columns]

# %%
sns.scatterplot(data=to_plot, x='text_len', 
                y='unique_char', hue='true')
# Out:
# <AxesSubplot:xlabel='text_len', ylabel='unique_char'>

# %%
line1= f"{to_plot[to_plot['unique_char']<20].count()[0]} articles used less than 20 unique characters in their text"
line2= f"{to_plot[to_plot['unique_char']<20].max()} is the longest piece of text that had less than 20 unique characters"
line3= f"{to_plot[to_plot['unique_char']>=20].mean().astype(int)} is the average length of the text, where the article had 20 or more unique characters"

print(colored(line1, 'green', attrs=['bold']))
print(colored(line2, 'blue', attrs=['bold']))
print(colored(line3, 'red', attrs=['bold']))

# %%
raw_df.sample()
# Out:
#                                                    title  \
# 25892  Clinton to release 2015 tax returns within day...
#
#                                                     text   subject  true  day  \
# 25892   - U.S. Democratic presidential candidate Hill...  politics     1   11
#
#        month  year
# 25892      8  2016

# %%
# function to remove HTML tags 

def remove_tags(text):
    
    # pass html content
    soup=BeautifulSoup(text, "html.parser")
    
    for data in soup(['style','script']):
        # remove tads 
        data.decompose()
        
    # return data be retrieveing tag content 
    return ' '.join(soup.strippe_strings)

# %%
raw_df['text'] = raw_df['text'].map(lmabda x: remove_tags(x))

# %% [markdown]
# #### Remove all special characters and numbers. Fold tect to Lowercase

# %%
# casefold 
raw_df['text'] = raw_df['text'].map(lambda x: x.casefold())

# %%
# punctuation 

def remove_punctuation_spec_char(text_):
    punctuation = string.punctuation
    text_ = ' '.join([word for word in text_.split() if word not in punctuation])
    text_ = ' '.join([re.sub(r'[a-zA-Z]','',word) for word in text_.split()])
    return text_

raw_df['text'] = raw_df['text'].map(lambda x: remove_punctuation_spec_char(x))

# %%
raw_df.sample(3)

# %%
cleaned_df = raw_df.copy()
cleaned_df.to_csv('cleaned_news.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## To do list:
# * Sentiment analysis
# * ML and Modelling
# * Write Project Report
